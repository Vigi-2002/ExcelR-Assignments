# %% [markdown]
# # Recommendation_System(Assignment)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import the dataset

# %%
df = pd.read_csv('anime.csv')

# %%
df.shape
# Out:
# (12294, 7)

# %%
df.head(5)
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
df.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %% [markdown]
# ## Find duplicated values

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12289    False
# 12290    False
# 12291    False
# 12292    False
# 12293    False
# Length: 12294, dtype: bool

# %%
df.loc[df.duplicated()] # Returns duplicated cell
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %% [markdown]
# NO duplicated values

# %%
df.isna().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %% [markdown]
# ## Handling NULL values

# %%
df['genre'].fillna('', inplace=True)

# %% [markdown]
# ## Preprocess and Vectorize

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorizer on genres
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['genre'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute Cosine Similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# ## Define Recommendation Function

# %%
def recommend_anime(title, df, cosine_sim, top_n=5):
    # Normalize input
    title = title.lower()
    
    # Get index of anime
    matches = df[df['name'].str.lower() == title]
    if matches.empty:
        return f"No anime found with title '{title}'"
    
    idx = matches.index[0]

    # Get similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]

    # Fetch recommended titles
    anime_indices = [i[0] for i in sim_scores]
    return df['name'].iloc[anime_indices].tolist()

# %%
recommendations = recommend_anime("Naruto", df, cosine_sim, top_n=5)
print("Recommendations:", recommendations)
# Out:
# Recommendations: ['Naruto: Shippuuden', 'Naruto', 'Boruto: Naruto the Movie - Naruto ga Hokage ni Natta Hi', 'Naruto x UT', 'Naruto: Shippuuden Movie 4 - The Lost Tower']

# %% [markdown]
# ## Define the recommendation function with threshold control

# %%
anime_indices = pd.Series(df.index, index=df['name'].str.lower())

def recommend_anime_by_threshold(title, df, cosine_sim, threshold=0.5):
    title = title.lower()
    if title not in anime_indices:
        return f"No anime found with title '{title}'"
    
    idx = anime_indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Filter by threshold and exclude itself
    filtered = [(i, score) for i, score in sim_scores if i != idx and score >= threshold]
    filtered = sorted(filtered, key=lambda x: x[1], reverse=True)
    
    # Return list of (title, similarity score)
    return [(df['name'].iloc[i], round(score, 3)) for i, score in filtered]

# %%
recommend_anime_by_threshold("Naruto", df, cosine_sim, threshold=0.3)
# Out:
# [('Boruto: Naruto the Movie', 1.0),
#  ('Naruto: Shippuuden', 1.0),
#  ('Boruto: Naruto the Movie - Naruto ga Hokage ni Natta Hi', 1.0),
#  ('Naruto x UT', 1.0),
#  ('Naruto: Shippuuden Movie 4 - The Lost Tower', 1.0),
#  ('Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsugu Mono', 1.0),
#  ('Naruto Shippuuden: Sunny Side Battle', 1.0),
#  ('Naruto Soyokazeden Movie: Naruto to Mashin to Mitsu no Onegai Dattebayo!!',
#   1.0),
#  ('Kyutai Panic Adventure!', 0.981),
#  ('Naruto: Shippuuden Movie 6 - Road to Ninja', 0.947),
#  ('Rekka no Honoo', 0.947),
#  ('Naruto: Honoo no Chuunin Shiken! Naruto vs. Konohamaru!!', 0.947),
#  ('Street Fighter Zero The Animation', 0.943),
#  ('Dragon Ball Z', 0.937),
#  ('Dragon Ball Kai (2014)', 0.937),
#  ('Dragon Ball Kai', 0.937),
#  ('Dragon Ball Z Movie 15: Fukkatsu no F', 0.937),
#  ('Dragon Ball Super', 0.937),
#  ('Dragon Ball Z: Summer Vacation Special', 0.937),
#  ('Dragon Ball Z: Atsumare! Gokuu World', 0.937),
#  ('Dragon Ball GT: Goku Gaiden! Yuuki no Akashi wa Suushinchuu', 0.937),
#  ('Dragon Ball Z Movie 11: Super Senshi Gekiha!! Katsu no wa Ore da', 0.937),
#  ('Kurokami The Animation', 0.937),
#  ('Project ARMS', 0.937),
#  ('Kurokami: Tora to Tsubasa', 0.937),
#  ('Kurokami: Intermission', 0.937),
#  ('Wolverine', 0.937),
#  ('Akai Hayate', 0.937),
#  ('The Last: Naruto the Movie', 0.935),
#  ('Iron Virgin Jun', 0.922),
#  ('Dragon Ball Z Movie 14: Kami to Kami', 0.917),
#  ('Variable Geo', 0.911),
#  ('Dragon Ball', 0.905),
#  ('Bulg-eunmae', 0.904),
#  ('Hokuto no Ken 2', 0.898),
#  ('Saint Seiya: The Lost Canvas - Meiou Shinwa 2', 0.897),
#  ('Saint Seiya: The Lost Canvas - Meiou Shinwa', 0.897),
#  ('Medaka Box Abnormal', 0.89),
#  ('Medaka Box', 0.89),
#  ('Tenjou Tenge', 0.89),
#  ('Gatchaman', 0.884),
#  ('Gakuen Tokusou Hikaruon', 0.884),
#  ('Dragon Ball: Episode of Bardock', 0.88),
#  ('Machine Robo: Leina, The Legend of Wolf Blade', 0.876),
#  ('Naruto: Shippuuden Movie 5 - Blood Prison', 0.876),
#  ('Ninja Hattori-kun Plus Perman: Chounouryoku Wars', 0.868),
#  ('Shin Hurricane Polymar', 0.865),
#  ('Dragon Ball Z: Zenbu Misemasu Toshi Wasure Dragon Ball Z!', 0.859),
#  ('Riki-Oh: Toukatsu Jigoku', 0.859),
#  ('Riki-Oh 2: Horobi no Ko', 0.859),
#  ('Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai', 0.858),
#  ('Project ARMS: The 2nd Chapter', 0.854),
#  ('Baoh Raihousha', 0.84),
#  ('Taboo Tattoo', 0.833),
#  ('Dragon Ball: Super Saiya-jin Zetsumetsu Keikaku', 0.826),
#  ('Ninja Hattori-kun Plus Perman: Ninja Kaijuu Jippou tai Miracle Tamago',
#   0.825),
#  ('Ikkitousen: Dragon Destiny', 0.822),
#  ('Ikkitousen: Great Guardians', 0.822),
#  ('Ikkitousen: Xtreme Xecutor', 0.822),
#  ('Ikkitousen: Shuugaku Toushi Keppuuroku', 0.822),
#  ('Yuusha Shirei Dagwon', 0.808),
#  ('Shadow Skill: Eigi', 0.804),
#  ('Battle Royal High School', 0.803),
#  ('Battle Spirits: Ryuuko no Ken', 0.801),
#  ('Mushibugyou', 0.797),
#  ('Mushibugyou OVA', 0.797),
#  ('Samurai Spirits 2: Asura Zanmaden', 0.789),
#  ('Ikkitousen: Dragon Destiny Specials', 0.787),
#  ('Ikkitousen', 0.787),
#  ('Street Fighter II: The Movie', 0.777),
#  ('Koukou Tekken-den Tough', 0.777),
#  ('Baki', 0.777),
#  ('Huang Feihong Yong Chuang Tianxia', 0.777),
#  ('Sengoku Basara Movie: The Last Party', 0.769),
#  ('Sengoku Basara Two', 0.769),
#  ('Sengoku Basara', 0.769),
#  ('Sengoku Basara: Judge End', 0.769),
#  ('Ikkitousen: Extravaganza Epoch', 0.768),
#  ('Virtua Fighter', 0.761),
#  ('Tatakae!! Ramenman', 0.761),
#  ('Ninku: Knife no Bohyou', 0.761),
#  ('Kenyuu Densetsu Yaiba', 0.76),
#  ('Rekka no Honoo: Final Burning', 0.756),
#  ('Maken-Ki! OVA', 0.755),
#  ('Maken-Ki!', 0.755),
#  ('Maken-Ki! Two', 0.755),
#  ('Ben-To', 0.746),
#  ('Shijou Saikyou no Deshi Kenichi', 0.741),
#  ('Shijou Saikyou no Deshi Kenichi OVA', 0.741),
#  ('Sakigake!! Otokojuku', 0.741),
#  ('Shijou Saikyou no Deshi Kenichi Specials', 0.741),
#  ('Kakutou Bijin Wulong: Rebirth', 0.741),
#  ('Sakigake!! Otokojuku Movie', 0.741),
#  ('Ranma ½: Akumu! Shunmin Kou', 0.736),
#  ('Katekyo Hitman Reborn!', 0.736),
#  ('Heungnyongwanggwa Bihodongja', 0.736),
#  ('Tatakae!! Ramenman (Movie)', 0.736),
#  ('Hokuto no Ken: Toki-den', 0.72),
#  ('Hokuto no Ken: Legend of Heroes', 0.72),
#  ('Toushinden', 0.72),
#  ('Double Hard', 0.72),
#  ('Feng Ji Yun Nu', 0.72),
#  ('Geori-eui Mubeopja', 0.72),
#  ('Shin Karate Jigoku-hen', 0.72),
#  ('Shinken Densetsu: Tight Road', 0.72),
#  ('Maji de Watashi ni Koi Shinasai!', 0.717),
#  ('Naruto: Shippuuden Movie 2 - Kizuna', 0.71),
#  ('Big Order', 0.709),
#  ('Big Order (TV)', 0.709),
#  ('Kyutai Panic Adventure Returns!', 0.709),
#  ('Ranma ½ OVA', 0.707),
#  ('Kizuna Ichigeki', 0.705),
#  ('Pyun Pyun Maru', 0.705),
#  ('Ranma ½: Chou Musabetsu Kessen! Ranma Team vs. Densetsu no Houou', 0.704),
#  ('Muteki Kanban Musume', 0.703),
#  ('To Heart: Remember My Memories Specials', 0.702),
#  ('Sasuke', 0.701),
#  ('Souten no Ken Specials', 0.701),
#  ('Street Fighter II: Yomigaeru Fujiwara-Kyou - Toki wo Kaketa Fighter-tachi',
#   0.701),
#  ('Sexy Commando Gaiden: Sugoiyo!! Masaru-san', 0.701),
#  ('Sexy Commando Gaiden: Sugoiyo!! Masaru-san Specials', 0.701),
#  ('Ninku (Movie)', 0.697),
#  ('Fatal Fury 2: The New Battle', 0.697),
#  ('Shin Hokuto no Ken', 0.694),
#  ('Toriko: Jump Super Anime Tour 2009 Special', 0.693),
#  ('Toriko: Barbarian Ivy wo Hokaku Seyo!', 0.693),
#  ('Naruto: Takigakure no Shitou - Ore ga Eiyuu Dattebayo!', 0.693),
#  ('One Piece: Romance Dawn', 0.692),
#  ('One Piece: Romance Dawn Story', 0.692),
#  ('Yuu☆Yuu☆Hakusho Picture Drama', 0.691),
#  ('Grappler Baki: Saidai Tournament-hen', 0.687),
#  ('Naruto: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo! Special: Konoha Annual Sports Festival',
#   0.684),
#  ('Crayon Shin-chan Manatsu no Yoru ni Ora Sanjou! Arashi wo Yobu Den-O vs. Shin-O 60-bu Special!!',
#   0.681),
#  ('Hokuto no Ken Zero: Kenshirou Den', 0.677),
#  ('Hokuto no Ken: Raoh Gaiden Junai-hen', 0.676),
#  ('Batman: Gotham Knight', 0.676),
#  ('Feng Yun Jue', 0.676),
#  ('Youseiki Suikoden', 0.676),
#  ('Toukiden Kiwami', 0.676),
#  ('Tiger &amp; Bunny Pilot', 0.676),
#  ('Osu!! Karate Bu', 0.674),
#  ('Boku no Hero Academia', 0.672),
#  ('Boku no Hero Academia: Jump Festa 2016 Special', 0.672),
#  ('Boku no Hero Academia 2nd Season', 0.672),
#  ('Hokuto no Ken: Raoh Gaiden Ten no Haoh', 0.672),
#  ('Ogami Matsugorou', 0.671),
#  ('Tekken Chinmi', 0.671),
#  ('Bleach', 0.666),
#  ('Bleach Movie 4: Jigoku-hen', 0.666),
#  ('Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu', 0.666),
#  ('Katekyo Hitman Reborn! x ēlDLIVE Special', 0.666),
#  ('Onikirimaru', 0.665),
#  ('Hunter x Hunter (2011)', 0.665),
#  ('Hunter x Hunter', 0.665),
#  ('Hunter x Hunter OVA', 0.665),
#  ('Hunter x Hunter: Greed Island Final', 0.665),
#  ('Hunter x Hunter: Greed Island', 0.665),
#  ('Hunter x Hunter Movie: Phantom Rouge', 0.665),
#  ('Hunter x Hunter Pilot', 0.665),
#  ('Hunter x Hunter Movie: The Last Mission', 0.665),
#  ('Nano Invaders', 0.665),
#  ('Taegeugsonyeon Huin Dogsuli', 0.665),
#  ('Xiao Taiji', 0.665),
#  ('Saint Seiya: Meiou Hades Elysion-hen', 0.664),
#  ('Hokuto no Ken', 0.661),
#  ('Himawari!', 0.661),
#  ('One Piece Film: Strong World Episode 0', 0.656),
#  ('One Piece: Episode of Luffy - Hand Island no Bouken', 0.656),
#  ('One Piece Movie 4: Dead End no Bouken', 0.656),
#  ('One Piece Movie 9: Episode of Chopper Plus - Fuyu ni Saku, Kiseki no Sakura',
#   0.656),
#  ('One Piece: Adventure of Nebulandia', 0.656),
#  ('One Piece Movie 5: Norowareta Seiken', 0.656),
#  ('One Piece: Umi no Heso no Daibouken-hen', 0.656),
#  ('One Piece: Oounabara ni Hirake! Dekkai Dekkai Chichi no Yume!', 0.656),
#  ('One Piece: Glorious Island', 0.656),
#  ('One Piece Recap', 0.656),
#  ('One Piece Movie 2: Nejimaki-jima no Daibouken', 0.656),
#  ('One Piece Movie 1', 0.656),
#  ('One Piece Movie 3: Chinjuu-jima no Chopper Oukoku', 0.656),
#  ('Dragon Ball Movie 1: Shen Long no Densetsu', 0.656),
#  ('One Piece Film: Gold Episode 0 - 711 ver.', 0.656),
#  ('One Piece: Taose! Kaizoku Ganzack', 0.656),
#  ('Kure-nai', 0.656),
#  ('Fatal Fury: The Motion Picture', 0.656),
#  ('Fatal Fury: Legend of the Hungry Wolf', 0.656),
#  ('Natsuki Crisis', 0.655),
#  ('Air Master', 0.655),
#  ('Kinnikuman II Sei: Ultimate Muscle 2', 0.655),
#  ('Kinnikuman II Sei: Ultimate Muscle', 0.655),
#  ('Kinnikuman II Sei', 0.655),
#  ('V.G.Neo The Animation', 0.653),
#  ('Getsumen To Heiki Mina Specials', 0.649),
#  ('Dragon Ball Specials', 0.648),
#  ('Hulu Xiongdi', 0.647),
#  ('THE REFLECTION', 0.647),
#  ('Sumomomo Momomo: Chijou Saikyou no Yome', 0.646),
#  ('Tales of Symphonia The Animation: Tethe&#039;alla-hen', 0.642),
#  ('Tales of Symphonia The Animation: Sekai Tougou-hen', 0.642),
#  ('Tales of Symphonia The Animation: Sylvarant-hen', 0.642),
#  ('Souten no Ken', 0.641),
#  ('Hon Ran', 0.64),
#  ('Blade &amp; Soul', 0.639),
#  ('Qin Shiming Yue Zhi: Guoqing Tebie Pian', 0.637),
#  ('Hokuto no Ken: Yuria-den', 0.636),
#  ('Shin Mazinger Shougeki! Z-hen', 0.635),
#  ('Dragon Fist', 0.633),
#  ('Choujin Gakuen Gowcaizer: The Voltage Fighters', 0.633),
#  ('Kakutou Bijin Wulong', 0.632),
#  ('Zettai Shougeki: Platonic Heart Picture Drama', 0.632),
#  ('Zettai Shougeki: Platonic Heart', 0.632),
#  ('009 Re:Cyborg x Zip', 0.63),
#  ('Sakuran Boy DT', 0.63),
#  ('Ultra B', 0.63),
#  ('Yuu☆Yuu☆Hakusho', 0.629),
#  ('Hokuto no Ken: Raoh Gaiden Gekitou-hen', 0.627),
#  ('Kurenai Sanshirou', 0.626),
#  ('Sugata Sanshirou', 0.626),
#  ('Ranma ½ Super', 0.625),
#  ('Shingeki no Kyojin', 0.623),
#  ('Shingeki no Kyojin OVA', 0.623),
#  ('Shingeki no Kyojin Movie 2: Jiyuu no Tsubasa', 0.623),
#  ('Shingeki no Kyojin Movie 1: Guren no Yumiya', 0.623),
#  ('Shingeki no Kyojin: Ano Hi Kara', 0.623),
#  ('Shingeki no Kyojin Season 2', 0.623),
#  ('One Piece', 0.622),
#  ('One Piece: Episode of Merry - Mou Hitori no Nakama no Monogatari', 0.622),
#  ('One Piece: Episode of Nami - Koukaishi no Namida to Nakama no Kizuna',
#   0.622),
#  ('One Piece: Episode of Sabo - 3 Kyoudai no Kizuna Kiseki no Saikai to Uketsugareru Ishi',
#   0.622),
#  ('Psychic Force', 0.621),
#  ('Dragon Ball Kai: Mirai ni Heiwa wo! Goku no Tamashii yo Eien ni', 0.619),
#  ('Code:Breaker', 0.618),
#  ('Shikabane Hime: Aka', 0.612),
#  ('Honoo no Tenkousei', 0.61),
#  ('Qin Shiming Yue Zhi: Zhu Zi Bai Jia', 0.609),
#  ('Qin Shiming Yue Zhi: Ye Jin Tianming', 0.609),
#  ('Qin Shiming Yue Zhi: Bai Bu Fei Jian', 0.609),
#  ('Qin Shiming Yue 3D: Dianying Longteng Wanli', 0.609),
#  ('Qin Shiming Yue Tebie Pian: Di Zi Jiang Xi', 0.609),
#  ('Qin Shiming Yue Zhi: Junlin Tianxia', 0.609),
#  ('Qin Shiming Yue Zhi: Luosheng Tangxia', 0.609),
#  ('Qin Shiming Yue Zhi: Tian Xing Jiu Ge', 0.609),
#  ('Qin Shiming Yue Zhi: Wanli Changcheng', 0.609),
#  ('Kill la Kill', 0.608),
#  ('Kill la Kill Special', 0.608),
#  ('Yozakura Quartet: Tsuki ni Naku', 0.606),
#  ('Yozakura Quartet: Hana no Uta', 0.606),
#  ('Yozakura Quartet: Hoshi no Umi', 0.606),
#  ('Yozakura Quartet', 0.606),
#  ('Sexy Sailor Soldiers', 0.605),
#  ('Tottemo! Luckyman', 0.605),
#  ('Sengoku Kitan Youtouden', 0.603),
#  ('Shin Hakkenden', 0.603),
#  ('Tekken', 0.603),
#  ('Beast Wars Neo', 0.602),
#  ('Ucchare Goshogawara', 0.601),
#  ('Tokyo ESP', 0.601),
#  ('Ninin ga Shinobuden', 0.6),
#  ('Hana no Zundamaru', 0.6),
#  ('Hana no Zundamaru: Junk', 0.6),
#  ('Bleach Movie 1: Memories of Nobody', 0.599),
#  ('Kosuke-sama Rikimaru-sama: Konpeitou no Ryuu', 0.599),
#  ('Final Fantasy VII: Advent Children Complete', 0.598),
#  ('Final Fantasy VII: Advent Children', 0.598),
#  ('Final Fantasy VII: On the Way to a Smile - Episode: Denzel', 0.598),
#  ('Spheres', 0.598),
#  ('Kyattou Ninden Teyandee', 0.598),
#  ('Elf 17', 0.598),
#  ('Landreaall', 0.597),
#  ('Mutsu Enmei Ryuu Gaiden: Shura no Toki', 0.595),
#  ('Yongshi', 0.595),
#  ('X-Men', 0.594),
#  ('Aquarian Age: Saga II - Don&#039;t Forget Me...', 0.594),
#  ('Kouryuu no Mimi: Mina no Shou', 0.594),
#  ('Dragon Ball Movie 4: Saikyou e no Michi', 0.593),
#  ('Dragon Ball Movie 3: Makafushigi Daibouken', 0.593),
#  ('Dragon Ball Movie 2: Majinjou no Nemuri Hime', 0.593),
#  ('Kage (OVA)', 0.592),
#  ('Princess Army: Wedding★Combat', 0.592),
#  ('D.Gray-man Hallow', 0.592),
#  ('Scryed Alteration I: Tao', 0.591),
#  ('Scryed Alteration II: Quan', 0.591),
#  ('Eat-Man &#039;98', 0.591),
#  ('Eat-Man', 0.591),
#  ('Sasuga no Sarutobi', 0.591),
#  ('Ranma ½: Battle ga Ippai 29-nin no Korinai Yatsura', 0.589),
#  ('Ranma ½: Totteoki Talk Best of Memories', 0.589),
#  ('Ranma ½: Tendou-ke no Oyobidenai Yatsura!', 0.589),
#  ('Ninja Hattori-kun', 0.589),
#  ('Ranma ½: 1994 Music Calendar', 0.589),
#  ('Ninja Hattori-kun: Nin Nin Ninpo Enikki no Maki', 0.589),
#  ('Giga Tribe', 0.587),
#  ('Marvel Disk Wars: The Avengers', 0.586),
#  ('Lightning Atom', 0.586),
#  ('Kiddy GiRL-AND', 0.585),
#  ('Mirai Kara Kita Shounen Super Jetter', 0.585),
#  ('Kamen no Maid Guy', 0.584),
#  ('Koihime†Musou', 0.582),
#  ('Kamen Rider Den-O: Imagin Anime 2', 0.582),
#  ('Kamen Rider Den-O: Imagin Anime', 0.582),
#  ('Kamen Rider Den-O: Imagin Anime 3', 0.582),
#  ('Hua Jianghu Zhi Ling Zhu', 0.579),
#  ('Ani*Kuri15', 0.577),
#  ('Sengoku Kitan Youtouden Soushuuhen', 0.577),
#  ('Kangetsu Ittou: Akuryou Kiri', 0.577),
#  ('Juubee-chan 2: Siberia Yagyuu no Gyakushuu', 0.577),
#  ('Sumomomo Momomo: Chijou Saikyou no Yome Specials', 0.575),
#  ('Tiger &amp; Bunny', 0.575),
#  ('Tiger &amp; Bunny Movie 2: The Rising', 0.575),
#  ('Tiger &amp; Bunny Movie 1: The Beginning', 0.575),
#  ('Tiger &amp; Bunny Recaps', 0.575),
#  ('Tiger &amp; Bunny: Too Many Cooks Spoil the Broth', 0.575),
#  ('Black Cat', 0.574),
#  ('Katanagatari', 0.573),
#  ('Tokyo Ravens', 0.572),
#  ('Tenjou Tenge: The Ultimate Fight', 0.571),
#  ('Tenjou Tenge: The Past Chapter', 0.571),
#  ('K: Missing Kings', 0.571),
#  ('K: Return of Kings', 0.571),
#  ('Towa no Quon 6: Towa no Quon', 0.571),
#  ('Towa no Quon 4: Guren no Shoushin', 0.571),
#  ('K', 0.571),
#  ('Towa no Quon 5: Souzetsu no Raifuku', 0.571),
#  ('Towa no Quon 3: Mugen no Renza', 0.571),
#  ('Towa no Quon 1: Utakata no Kaben', 0.571),
#  ('Hitori no Shita: The Outcast', 0.571),
#  ('Giant Robo the Animation: Chikyuu ga Seishi Suru Hi', 0.569),
#  ('Tetsuwan Atom: Ivan no Wakusei - Robot to Ningen no Yuujou', 0.569),
#  ('Asu no Yoichi!', 0.569),
#  ('Ultraman Kids no Kotowaza Monogatari', 0.569),
#  ('Backkom Specials', 0.569),
#  ('Omakase! Miracle Cat-dan', 0.569),
#  ('Super Backkom', 0.569),
#  ('Inazuma Eleven', 0.568),
#  ('Inazuma Eleven: Saikyou Gundan Ogre Shuurai', 0.568),
#  ('Inazuma Eleven Go: Chrono Stone', 0.568),
#  ('Inazuma Eleven Go', 0.568),
#  ('Inazuma Eleven Go: Galaxy', 0.568),
#  ('Inazuma Eleven: Chou Jigen Dream Match', 0.568),
#  ('Inazuma Eleven Go Recap', 0.568),
#  ('Ultraman Graffiti', 0.568),
#  ('GetBackers', 0.567),
#  ('Wu Geng Ji', 0.565),
#  ('Believe', 0.564),
#  ('Code:Breaker OVA', 0.564),
#  ('Ranma ½', 0.562),
#  ('Yume Senshi Wingman', 0.562),
#  ('Senkou no Night Raid Picture Drama', 0.562),
#  ('Shenmue: The Movie', 0.561),
#  ('Dies Irae', 0.56),
#  ('Dragon Quest: Dai no Daibouken', 0.56),
#  ('Tekken: Blood Vengeance', 0.559),
#  ('Baka to Test to Shoukanjuu: Matsuri', 0.559),
#  ('Kunoichi Gakuen Ninpouchou', 0.558),
#  ('Mahou Shoujo Lyrical Nanoha: The Movie 2nd A&#039;s', 0.557),
#  ('Mahou Shoujo Lyrical Nanoha A&#039;s', 0.557),
#  ('Mahou Shoujo Lyrical Nanoha: The Movie 1st', 0.557),
#  ('Mahou Shoujo Lyrical Nanoha StrikerS', 0.557),
#  ('Mahou Shoujo Lyrical Nanoha', 0.557),
#  ('Mahou Shoujo Lyrical Nanoha Reflection', 0.557),
#  ('Tokyo Underground', 0.555),
#  ('Ninja Hattori-kun: Nin Nin Furusato Daisakusen no Maki', 0.555),
#  ('Mutant Turtles: Choujin Densetsu-hen', 0.555),
#  ('Kaitouranma The Animation', 0.554),
#  ('Toaru Kagaku no Railgun S', 0.554),
#  ('Toaru Kagaku no Railgun', 0.554),
#  ('Toaru Kagaku no Railgun: Misaka-san wa Ima Chuumoku no Mato desukara',
#   0.554),
#  ('Witchblade', 0.554),
#  ('Solty Rei', 0.554),
#  ('Guilty Crown Kiseki: Reassortment', 0.554),
#  ('Kiddy GiRL-AND Pilot', 0.554),
#  ('Persona: Trinity Soul', 0.554),
#  ('Ougon Bat', 0.554),
#  ('Choujin Locke', 0.554),
#  ('Choujin Locke: Lord Leon', 0.554),
#  ('Choujin Locke: Shinsekai Sentai', 0.554),
#  ('Choujin Locke: Mirror Ring', 0.554),
#  ('Ai City', 0.554),
#  ('Choujin Locke Special', 0.554),
#  ('Jeonja Ingan 337', 0.554),
#  ('Armed Blue: Gunvolt', 0.554),
#  ('Esper Mami Special: My Angel Mami-chan', 0.553),
#  ('Yawara! Special: Zutto Kimi no Koto ga... .', 0.552),
#  ('Kinnikuman II Sei: Muscle Ninjin Soudatsu sen! Choujin Daisensou', 0.552),
#  ('Mini Hama: Minimum Hamatora', 0.551),
#  ('Dragon Ball GT', 0.549),
#  ('Wonder Momo', 0.549),
#  ('Jankenman', 0.548),
#  ('&quot;Eiyuu&quot; Kaitai', 0.548),
#  ('Tenkai Knights', 0.547),
#  ('Chiisana Kyojin Microman', 0.547),
#  ('Saber Marionette J', 0.547),
#  ('Infini-T Force', 0.547),
#  ('Chiisana Kyojin Microman: Daigekisen! Microman vs. Saikyou Senshi Gorgon',
#   0.546),
#  ('The Ultraman', 0.545),
#  ('Magma Taishi', 0.545),
#  ('Ultraman: Chou Toushi Gekiden - Suisei Senjin Tsuifon Toujou', 0.545),
#  ('Speed Grapher', 0.543),
#  ('Skull Man', 0.543),
#  ('Ranma ½: DoCo Music Video', 0.541),
#  ('Ishii Hisaichi no Nanda Kanda Gekijou', 0.541),
#  ('Sacred Seven: Shirogane no Tsubasa Picture Drama', 0.539),
#  ('Tactics', 0.537),
#  ('The Choujo', 0.536),
#  ('Charamaru-kun to Dokumaru-kun', 0.535),
#  ('Otenki Boys', 0.535),
#  ('Ultraman Kids: M7.8 Sei no Yukai na Nakama', 0.535),
#  ('Sengoku Basara: Setonai no Gekitotsu! Hi wo Fuku Umi no Daiyousai - Fugaku!!',
#   0.534),
#  ('Miyamoto Musashi: Souken ni Haseru Yume', 0.534),
#  ('Juusenshi Gulkeeva', 0.534),
#  ('K: Seven Stories', 0.534),
#  ('Project A-Ko 2: Daitokuji Zaibatsu no Inbou', 0.533),
#  ('Project A-Ko 4: Final', 0.533),
#  ('Project A-Ko 3: Cinderella Rhapsody', 0.533),
#  ('Karakuri no Kimi', 0.532),
#  ('Pa-Pa-Pa the ★ Movie: Perman - Tako de Pon! Ashi wa Pon!', 0.532),
#  ('Perman: Birdman ga Yatte Kita!!', 0.532),
#  ('Sore Ike! Anpanman: Kirakira Boshi no Namida', 0.532),
#  ('Momotaros no Natsuyasumi', 0.532),
#  ('Sore Ike! Anpanman: Franken-Robo-kun&#039;s Surprised Christmas', 0.532),
#  ('Sore Ike! Anpanman: Sing! Dance! Everybody&#039;s Christmas', 0.532),
#  ('Sentou Yousei Shoujo Tasukete! Mave-chan', 0.53),
#  ('Examurai Sengoku', 0.53),
#  ('Tondemo Senshi Muteking', 0.529),
#  ('Munto: Toki no Kabe wo Koete', 0.528),
#  ('Toaru Majutsu no Index 10th Anniversary PV', 0.528),
#  ('Yawara!', 0.528),
#  ('Yawara! Sore Yuke Koshinuke Kids!!', 0.528),
#  ('Arcade Gamer Fubuki', 0.528),
#  ('Taimanin Asagi', 0.527),
#  ('Taimanin Asagi Special', 0.527),
#  ('Afro Samurai Pilot', 0.526),
#  ('Karate Baka Ichidai', 0.526),
#  ('The Hakkenden', 0.526),
#  ('The Hakkenden: Shin Shou', 0.526),
#  ('Juubee Ninpuuchou: Ryuuhougyoku-hen', 0.526),
#  ('R.O.D the TV', 0.525),
#  ('Charlotte: Tsuyoi Monotachi', 0.525),
#  ('Re:␣Hamatora', 0.525),
#  ('Hamatora The Animation', 0.525),
#  ('Tantei Opera Milky Holmes Dai 2 Maku', 0.525),
#  ('Fw:Hamatora', 0.525),
#  ('Tantei Opera Milky Holmes: Summer Special', 0.525),
#  ('Tantei Opera Milky Holmes', 0.525),
#  ('Hamatora The Animation: Saishuukai Chokuzen! Mao ga Okuru Soushuuhen Special',
#   0.525),
#  ('Tantei Opera Milky Holmes: Alternative', 0.525),
#  ('Tantei Kageki Milky Holmes TD', 0.525),
#  ('Futari wa Milky Holmes', 0.525),
#  ('Tantei Opera Milky Holmes Movie: Gyakushuu no Milky Holmes', 0.525),
#  ('Tantei Opera Milky Holmes: Fun Fun Party Night♪ - Ken to Janet no Okurimono',
#   0.525),
#  ('Needless', 0.523),
#  ('Hagure Yuusha no Aesthetica', 0.522),
#  ('Guilty Crown', 0.52),
#  ('Guilty Crown: Lost Christmas', 0.52),
#  ('A-Ko The Versus', 0.519),
#  ('Astro Boy: Tetsuwan Atom', 0.519),
#  ('Himitsukessha Taka no Tsume', 0.518),
#  ('Himitsukessha Taka no Tsume Countdown', 0.518),
#  ('Himitsukessha Taka no Tsume DO', 0.518),
#  ('Himitsukessha Taka no Tsume EX', 0.518),
#  ('Himitsukessha Taka no Tsume GT', 0.518),
#  ('Himitsukessha Taka no Tsume MAX', 0.518),
#  ('Himitsukessha Taka no Tsume NEO', 0.518),
#  ('Himitsukessha Taka no Tsume The Movie 1: Soutou wa Nido Shinu', 0.518),
#  ('Himitsukessha Taka no Tsume The Movie 2: Watashi wo Aishita Kuro Oolong-Cha',
#   0.518),
#  ('Himitsukessha Taka no Tsume The Movie 3: http://takanotsume.jp wa Eien ni',
#   0.518),
#  ('himitsukesshatakanotsume.jp', 0.518),
#  ('Taka no Tsume NEO Announcement Movie', 0.518),
#  ('Takanotsume GO: Utsukushiki Elleair Shoushuu Plus', 0.518),
#  ('Edokko Boy: Gatten Tasuke', 0.518),
#  ('Tatakau Shisho: The Book of Bantorra', 0.517),
#  ('Yajikita Gakuen Douchuuki', 0.517),
#  ('Yuugen Kaisha', 0.516),
#  ('Aa Harimanada', 0.516),
#  ('Ninpuu Kamui Gaiden', 0.516),
#  ('Ninpuu Kamui Gaiden: Tsukihigai no Maki', 0.516),
#  ('Perman (1983)', 0.515),
#  ('Henshin Gattai! 5 tsu no Atsuki Tamashii', 0.512),
#  ('Baka to Test to Shoukanjuu Ni!', 0.512),
#  ('Baka to Test to Shoukanjuu', 0.512),
#  ('Baka to Test to Shoukanjuu: Spinout! Sore ga Bokura no Nichijou', 0.512),
#  ('Cosmo Police Justy', 0.511),
#  ('Project A-Ko', 0.51),
#  ('Time Bokan Series: Zenderman', 0.51),
#  ('Sacred Seven: Shirogane no Tsubasa', 0.508),
#  ('Sacred Seven', 0.508),
#  ('Claymore', 0.508),
#  ('Cyborg 009 VS Devilman', 0.505),
#  ('Pokopon no Yukai na Saiyuuki', 0.505),
#  ('Highschool Aurabuster: Hikari no Mezame', 0.504),
#  ('11eyes', 0.503),
#  ('Sekirei: Pure Engagement', 0.503),
#  ('Sekirei', 0.503),
#  ('Yumeria', 0.503),
#  ('Kono Danshi, Uchuujin to Tatakaemasu.', 0.502),
#  ('Double Circle', 0.502),
#  ('Yuusha-Ou GaoGaiGar Final Grand Glorious Gathering', 0.502),
#  ('Kiddy Grade: Truth Dawn', 0.502),
#  ('Kiddy Grade: Maelstrom', 0.502),
#  ('Kiddy Grade: Ignition', 0.502),
#  ('Psychoarmor Govarian', 0.502),
#  ('Umi kara no Shisha', 0.502),
#  ('Chou Seimeitai Transformers Beast Wars Metals: Convoy Daihenshin!', 0.502),
#  ('Hua Jiang Hu Zhi Bu Liang Ren', 0.501),
#  ('Sore Ike! Anpanman: Yomigaere Bananajima', 0.501),
#  ('Kazemakase Tsukikage Ran', 0.5),
#  ('Saint Seiya: Meiou Hades Meikai-hen', 0.499),
#  ('Rolling☆Girls', 0.499),
#  ('Kekkai Sensen', 0.498),
#  ('Kekkai Sensen: Ousama no Restaurant no Ousama', 0.498),
#  ('Kekkai Sensen: Soresaemo Saitei de Saikou na Hibi', 0.498),
#  ('Bayonetta: Bloody Fate', 0.497),
#  ('Monkey King: Hero Is Back', 0.497),
#  ('Toaru Majutsu no Index II', 0.497),
#  ('Toaru Majutsu no Index: Endymion no Kiseki', 0.497),
#  ('Toaru Majutsu no Index', 0.497),
#  ('Toaru Majutsu no Index: Endymion no Kiseki Special', 0.497),
#  ('Tokyo Majin Gakuen Kenpucho: Tou', 0.496),
#  ('Towa no Quon 2: Konton no Ranbu', 0.496),
#  ('Makai Kishi Ingrid', 0.495),
#  ('Azarashi Tama-chan no Hi no Youjin', 0.494),
#  ('s.CRY.ed', 0.494),
#  ('Gifuu Doudou!!: Kanetsugu to Keiji', 0.493),
#  ('Shinshuu Sudama-hen', 0.493),
#  ('Sora wo Miageru Shoujo no Hitomi ni Utsuru Sekai', 0.492),
#  ('Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen', 0.491),
#  ('Crying Freeman', 0.491),
#  ('Code Geass: Hangyaku no Lelouch R2 Special Edition Zero Requiem', 0.49),
#  ('Kimagure Orange☆Road', 0.487),
#  ('Izumo: Takeki Tsurugi no Senki', 0.486),
#  ('Charlotte', 0.486),
#  ('Senkou no Night Raid', 0.486),
#  ('Senkou no Night Raid Specials', 0.486),
#  ('Senkou no Night Raid: Yogen', 0.486),
#  ('Zinba', 0.485),
#  ('11eyes: Momoiro Genmutan', 0.485),
#  ('Darker than Black: Kuro no Keiyakusha', 0.485),
#  ('Darker than Black: Kuro no Keiyakusha Gaiden', 0.485),
#  ('Darker than Black: Ryuusei no Gemini', 0.485),
#  ('Tenjou-jin to Akuto-jin Saigo no Tatakai', 0.484),
#  ('Tokyo Majin Gakuen Kenpucho: Tou Dai Ni Maku', 0.484),
#  ('Mini Hama: Minimum Hamatora Movies', 0.482),
#  ('Shin Onimusha: Dawn of Dreams the Story', 0.481),
#  ('Nanako SOS', 0.48),
#  ('Bakuretsu Hunters OVA', 0.478),
#  ('Yuusei Shounen Papii', 0.478),
#  ('Kyoushoku Soukou Guyver (1989)', 0.477),
#  ('Kyoushoku Soukou Guyver', 0.477),
#  ('Shigurui', 0.476),
#  ('Dororon Enma-kun Meeramera', 0.471),
#  ('Aquarian Age: Sign for Evolution', 0.471),
#  ('The Gakuen Choujo-tai', 0.471),
#  ('Sabu to Ichi Torimono Hikae', 0.47),
#  ('Hwanggeum Cheolin', 0.468),
#  ('Chikyuu Bouei Kazoku Special', 0.468),
#  ('Akai Kiba: Blue Sonnet', 0.468),
#  ('Soujuu Senshi Psychic Wars', 0.466),
#  ('Gungrave', 0.464),
#  ('DRAMAtical Murder', 0.464),
#  ('Makai Tenshi Djibril: Episode 2', 0.459),
#  ('Giant Robo Gaiden Ginrei', 0.458),
#  ('Shaolin Wuzang', 0.458),
#  ('Narara Wondeogongju', 0.457),
#  ('Tentai Senshi Sunred 2nd Season', 0.457),
#  ('Tentai Senshi Sunred', 0.457),
#  ('Tentai Senshi Sunred: Short Corner', 0.457),
#  ('Code Geass: Hangyaku no Lelouch Special Edition Black Rebellion', 0.457),
#  ('Code Geass: Hangyaku no Lelouch Recaps', 0.457),
#  ('Masamune Datenicle', 0.456),
#  ('Kurau Phantom Memory', 0.455),
#  ('Mekakucity Actors', 0.454),
#  ('Mekakucity Reload', 0.454),
#  ('Asagiri no Miko', 0.454),
#  ('Kiddy Grade', 0.454),
#  ('Mafukiden: Pandarian', 0.454),
#  ('Erementar Gerad', 0.452),
#  ('Seikon no Qwaser', 0.452),
#  ('Seikon no Qwaser II', 0.452),
#  ('Seikon no Qwaser: Jotei no Shouzou', 0.452),
#  ('First Squad: The Moment of Truth', 0.451),
#  ('Wrestler Gundan Seisenshi Robin Jr.', 0.45),
#  ('Joukamachi no Dandelion', 0.45),
#  ('Sengoku Otome: Momoiro Paradox', 0.449),
#  ('InuYasha: Toki wo Koeru Omoi', 0.449),
#  ('Negima!? Haru Special!?', 0.448),
#  ('Chou Henshin Cosprayers', 0.448),
#  ('Fushigi Yuugi', 0.447),
#  ('Fushigi Yuugi OVA 2', 0.446),
#  ('Ga-Rei: Zero', 0.445),
#  ('Ippatsu Hicchuu!! Devander', 0.444),
#  ('Fusha no Sha', 0.444),
#  ('Tengen Toppa Gurren Lagann Movie: Lagann-hen', 0.443),
#  ('Freezing', 0.442),
#  ('Hurricane Polymar', 0.441),
#  ('Muramasa', 0.441),
#  ('Sailor Senshi Venus♥Five', 0.441),
#  ('Kämpfer für die Liebe', 0.441),
#  ('One Punch Man', 0.439),
#  ('One Punch Man Specials', 0.439),
#  ('One Punch Man: Road to Hero', 0.439),
#  ('One Punch Man 2', 0.439),
#  ('Sousei no Aquarion', 0.439),
#  ('Sousei no Aquarion OVA', 0.439),
#  ('Dr.', 0.439),
#  ('Punch Line', 0.438),
#  ('Kekkai Sensen &amp; Beyond', 0.432),
#  ('Super Doll Licca-chan: Licca-chan Zettai Zetsumei! Doll Knights no Kiseki',
#   0.432),
#  ('C: The Money of Soul and Possibility Control', 0.432),
#  ('Koroshiya 1 The Animation: Episode 0', 0.432),
#  ('Konjiki no Gash Bell!!: Ougon no Chichi wo Motsu Otoko', 0.431),
#  ('X', 0.428),
#  ('Dark Cat', 0.428),
#  ('Aoharu x Kikanjuu: Kemono-tachi no Senjou da na!', 0.427),
#  ('Black Cat Special', 0.427),
#  ('Ansatsu Kyoushitsu', 0.427),
#  ('Shounan Bakusouzoku', 0.427),
#  ('Lupin III: Pilot Film', 0.427),
#  ('Abashiri Ikka', 0.427),
#  ('Code Geass: Hangyaku no Lelouch R2', 0.427),
#  ('Code Geass: Fukkatsu no Lelouch', 0.427),
#  ('Mobile Fighter G Gundam', 0.423),
#  ('Midnight Eye: Gokuu II', 0.423),
#  ('Youjuu Toshi', 0.422),
#  ('Code Geass: Hangyaku no Lelouch', 0.42),
#  ('Souryuuden', 0.42),
#  ('Esper Mami', 0.415),
#  ('Freezing Vibration', 0.415),
#  ('Mitama: Nin', 0.415),
#  ('Kawasaki Frontale x Tentai Senshi Sunred 2nd Season', 0.414),
#  ('Kawasaki Frontale x Tentai Senshi Sunred', 0.414),
#  ('Demashita! Powerpuff Girls Z', 0.413),
#  ('Sakurada Reset', 0.412),
#  ('Shin Shirayuki-hime Densetsu Prétear', 0.411),
#  ('Kara no Kyoukai Remix: Gate of Seventh Heaven', 0.411),
#  ('Mahou Sensei Negima!', 0.41),
#  ('Gegege no Kitarou (1971)', 0.41),
#  ('Gegege no Kitarou: Kitarou no Yuurei Densha', 0.41),
#  ('Miracle Shoujo Limit-chan', 0.408),
#  ('Kämpfer', 0.404),
#  ('Brave 10', 0.403),
#  ('Vampire Sensou', 0.4),
#  ('Persona 4 the Animation: The Factor of Hope', 0.394),
#  ('Ultraman M78 Gekijou: Love and Peace', 0.392),
#  ('Choukou Tenshi Escalayer', 0.391),
#  ('Battle Spirits: Brave', 0.38),
#  ('Battle Spirits: Sword Eyes', 0.38),
#  ('Battle Spirits: Heroes', 0.38),
#  ('Toumei Shounen Tantei Akira', 0.38),
#  ('Concrete Revolutio: Choujin Gensou - The Last Song', 0.377),
#  ('Concrete Revolutio: Choujin Gensou', 0.377),
#  ('Yes! Precure 5 GoGo! Movie: Okashi no Kuni no Happy Birthday', 0.377),
#  ('Kakugo no Susume', 0.371),
#  ('D.Gray-man', 0.364),
#  ('Lupin III (2015)', 0.364),
#  ('Lupin III: Part II', 0.364),
#  ('Lupin III', 0.364),
#  ('Lupin III: Part III', 0.364),
#  ('Lupin III: Kutabare! Nostradamus', 0.364),
#  ('Lupin III: Fuuma Ichizoku no Inbou', 0.364),
#  ('Lupin III: Chi no Kokuin - Eien no Mermaid', 0.364),
#  ('Lupin III (2015) Specials', 0.364),
#  ('Lupin III: $1 Money Wars', 0.364),
#  ('Lupin III: Dead or Alive', 0.364),
#  ('Lupin III: Nusumareta Lupin', 0.364),
#  ('Lupin III: Alcatraz Connection', 0.364),
#  ('Lupin III: Tenshi no Tactics - Yume no Kakera wa Koroshi no Kaori', 0.364),
#  ('Lupin III: Moeyo Zantetsuken!', 0.364),
#  ('Lupin III: Seven Days Rhapsody', 0.364),
#  ('Lupin III: Twilight Gemini no Himitsu', 0.364),
#  ('Lupin III: Harimao no Zaihou wo Oe!!', 0.364),
#  ('Lupin III: Princess of the Breeze - Kakusareta Kuuchuu Toshi', 0.364),
#  ('Lupin III: Lupin Ansatsu Shirei', 0.364),
#  ('Lupin III: Kiri no Elusive', 0.364),
#  ('Lupin III: Ai no Da Capo - Fujiko&#039;s Unlucky Days', 0.364),
#  ('Lupin III: Bye Bye Liberty - Kiki Ippatsu!', 0.364),
#  ('Lupin III: Napoleon no Jisho wo Ubae', 0.364),
#  ('Naruto: The Cross Roads', 0.364),
#  ('Lupin III: Russia yori Ai wo Komete', 0.364),
#  ('Toriko 3D: Kaimaku Gourmet Adventure!!', 0.364),
#  ('Lupin III: Babylon no Ougon Densetsu', 0.364),
#  ('Lupin III (2015): Italian Game', 0.364),
#  ('Duel Masters Cross', 0.364),
#  ('Duel Masters Cross Shock', 0.364),
#  ('Duel Masters Movie 2: Lunatic God Saga', 0.364),
#  ('Duel Masters Charge', 0.364),
#  ('Duel Masters Victory', 0.364),
#  ('Duel Masters Victory V', 0.364),
#  ('Duel Masters VS', 0.364),
#  ('Duel Masters Victory V3', 0.364),
#  ('Duel Masters', 0.364),
#  ('Duel Masters VSR', 0.364),
#  ('Duel Masters VSRF', 0.364),
#  ('Duel Masters: Hamukatsu to Dogiragon no Curry-pan Daibouken', 0.364),
#  ('Senyuu. Specials', 0.363),
#  ('Persona 4 the Animation', 0.362),
#  ('Persona 4 the Animation: No One is Alone', 0.362),
#  ('Persona 4 the Golden Animation', 0.362),
#  ('Shingetsutan Tsukihime', 0.362),
#  ('Chuuka Ichiban!', 0.358),
#  ('Yoru ga Kuru!', 0.357),
#  ('Hellsing I: Digest for Freaks', 0.351),
#  ('Kyou kara Ore wa!!', 0.35),
#  ('Yakitate!! Japan', 0.35),
#  ('Katekyo Hitman Reborn! Special', 0.35),
#  ('Mister Ajikko', 0.35),
#  ('Urayasu Tekkin Kazoku', 0.35),
#  ('Nintama Rantarou', 0.35),
#  ('Koro-sensei Q!', 0.35),
#  ('Okusama ga Seitokaichou!: Okusama Gekijou', 0.35),
#  ('Nintama Rantarou Movie: Ninjutsu Gakuen Zenin Shutsudou! no Dan', 0.35),
#  ('Okusama ga Seitokaichou! OVA: Okusama Gekijou', 0.35),
#  ('Nintama Rantarou Movie', 0.35),
#  ('Takamiya Nasuno Desu!: Teekyuu Spin-off', 0.35),
#  ('Ganbare Goemon', 0.35),
#  ('Maido! Urayasu Tekkin Kazoku', 0.35),
#  ('Takamiya Nasuno Desu!: Teekyuu Spin-off Specials', 0.35),
#  ('Chuuko Video-ya no Onna Tenin X', 0.35),
#  ('Donkikko', 0.35),
#  ('Ganbare Goemon: Chikyuu Kyuushutsu Daisakusen', 0.35),
#  ('Mister Ajikko Special', 0.35),
#  ('Toppuku Kyousou Kyoku', 0.35),
#  ('Kamen Rider Fourze x Crayon Shin-chan', 0.349),
#  ('Yokohama Bakkure-tai', 0.346),
#  ('Ansatsu Kyoushitsu (TV) 2nd Season', 0.339),
#  ('Ansatsu Kyoushitsu (TV)', 0.339),
#  ('Ansatsu Kyoushitsu (TV) 2nd Season: Kagaijugyou-hen', 0.339),
#  ('Ansatsu Kyoushitsu: 365-nichi no Jikan', 0.339),
#  ('Ansatsu Kyoushitsu (TV): Deai no Jikan', 0.339),
#  ('Udauda Yatteru Hima wa Nee!', 0.339),
#  ('Zettai Karen Children', 0.333),
#  ('Shaman King Specials', 0.333),
#  ('Zettai Karen Children OVA: Aitazousei! Ubawareta Mirai?', 0.333),
#  ('Zettai Karen Children Gentei Kaikin!! OVA Chou Sakidori Special!!', 0.333),
#  ('Zettai Karen Children Recap', 0.333),
#  ('Toriko', 0.322),
#  ('Naruto: Shippuuden Movie 1', 0.322),
#  ('Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku', 0.322),
#  ('MÄR', 0.322),
#  ('One Piece 3D: Mugiwara Chase', 0.322),
#  ('One Piece 3D: Gekisou! Trap Coaster', 0.322),
#  ('Hitsugi no Chaika OVA', 0.322),
#  ('Digimon Xros Wars', 0.322),
#  ('Digimon Savers the Movie: Kyuukyoku Power! Burst Mode Hatsudou!!', 0.322),
#  ('Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 0.322),
#  ('Defend Love', 0.32),
#  ('Juubee-chan: Lovely Gantai no Himitsu', 0.318),
#  ('Tetsuwan Birdy', 0.315),
#  ('Viewtiful Joe', 0.315),
#  ('Chikyuu Bouei Kazoku', 0.315),
#  ('Fight Da!! Pyuta', 0.315),
#  ('Yuu☆Yuu☆Hakusho: Meikai Shitou-hen - Honoo no Kizuna', 0.313),
#  ('Kure-nai OVA', 0.313),
#  ('Aachi wa Ssipak', 0.313),
#  ('Nekojiru Gekijou Jirujiru Original', 0.313),
#  ('Kara no Kyoukai: Manner Movies', 0.313),
#  ('MonHun Nikki Girigiri Airou Mura G', 0.313),
#  ('MonHun Nikki Girigiri Airou Mura: Airou Kiki Ippatsu', 0.313),
#  ('Ushio to Tora: Comically Deformed Theater', 0.313),
#  ('Chokin Senshi Cashman', 0.313),
#  ('Inferno Cop Specials', 0.313),
#  ('Katsura Hime', 0.313),
#  ('Benkei tai Ushiwaka', 0.313),
#  ('Arisa☆Good Luck', 0.313),
#  ('Majin Sentai Death Ranger: Ubawareta Pudding!', 0.313),
#  ('MonHun Nikki Girigiri Airou Mura: Airou Kiki Ippatsu Specials', 0.313),
#  ('Nanbo no Monjai! 2: Yankee Gurentai', 0.313),
#  ('Nanbo no Monjai! Yankee Gurentai', 0.313),
#  ('Naniwa Yuukyouden', 0.313),
#  ('Naniwa Yuukyouden: Chou Gokudou! Yoru no Bat wa Manrui-hen', 0.313),
#  ('Naniwa Yuukyouden: Kanketsu-hen', 0.313),
#  ('Naniwa Yuukyouden: Kyouretsu! Ana ga Attara Iretai-hen', 0.313),
#  ('Naniwa Yuukyouden: Nekketsu!! Bakushou Mankai-hen', 0.313),
#  ('Pepsi Nex x 009 Re:Cyborg', 0.313),
#  ('Teppen', 0.313),
#  ('Tough Guy!', 0.313),
#  ('Youkai Ninpouchou Jiraiya! Special', 0.313),
#  ('Zoku Naniwa Yuukyouden', 0.313),
#  ('Noragami Aragoto OVA', 0.312),
#  ('Noragami OVA', 0.312),
#  ('Allison to Lillia', 0.312),
#  ('B&#039;T X Neo', 0.312),
#  ('Kouya no Shounen Isamu', 0.312),
#  ('Super Street Fighter IV', 0.312),
#  ('Street Fighter: Aratanaru Kizuna', 0.312),
#  ('Gene Diver', 0.312),
#  ('Gongnyong Baengmannyeon Ttori', 0.312),
#  ('Juushin Enbu: Hero Tales', 0.311),
#  ('Monster Farm 5: Circus Caravan OVA - Kessei!! Orcoro Circus', 0.311),
#  ('Shinrabanshou: Tenchi Shinmei no Shou', 0.311),
#  ('Tobe! Isami', 0.309),
#  ('Prince of Tennis: The National Tournament', 0.309),
#  ('Eyeshield 21', 0.309),
#  ('New Prince of Tennis OVA vs. Genius10', 0.309),
#  ('New Prince of Tennis', 0.309),
#  ('New Prince of Tennis Specials', 0.309),
#  ('Ganbare Genki', 0.309),
#  ('Aoharu x Kikanjuu', 0.309),
#  ('Kinnikuman: Kinnikusei Oui Soudatsu-hen', 0.309),
#  ('Prince of Tennis: Oshougatsu Special', 0.309),
#  ('Eyeshield 21: Jump Festa 2005 Special', 0.309),
#  ('Kinnikuman (1984)', 0.309),
#  ('Kinnikuman: Kessen! Shichinin no Seigi Choujin vs. Uchuu Nobushi', 0.309),
#  ('Kinnikuman: Ooabare! Seigi Choujin', 0.309),
#  ('Kinnikuman: New York Kiki Ippatsu!', 0.309),
#  ('Kinnikuman: Gyakushuu! Uchuu Kakure Choujin', 0.309),
#  ('Kinnikuman: Haresugata! Seigi Choujin', 0.309),
#  ('Kinnikuman: Seigi Choujin vs. Kodai Choujin', 0.309),
#  ('Kinnikuman: Seigi Choujin vs. Senshi Choujin', 0.309),
#  ('Weiß Kreuz', 0.306),
#  ('Weiß Kreuz Glühen', 0.306),
#  ('Phantom The Animation', 0.306),
#  ('Otoko Ippiki Gaki Daishou', 0.306),
#  ('Ttoli Janggun', 0.306),
#  ('City Hunter 2', 0.305),
#  ('Lupin III vs. Detective Conan: The Movie', 0.305),
#  ('City Hunter', 0.305),
#  ('City Hunter 3', 0.305),
#  ('City Hunter &#039;91', 0.305),
#  ('City Hunter: Ai to Shukumei no Magnum', 0.305),
#  ('City Hunter: The Secret Service', 0.305),
#  ('City Hunter: Hyakuman Dollar no Inbou', 0.305),
#  ('City Hunter: Bay City Wars', 0.305),
#  ('Lupin III: Green vs. Red', 0.305),
#  ('Hareluya II Boy', 0.304)]

# %% [markdown]
# ## Splitting the data using a small portion of original datset as the dataset 'anime.csv' was throwing multiple errors during recomendation.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import precision_score, recall_score, f1_score

# Create a small synthetic dataset
data = {
    'name': [
        'Naruto', 'Bleach', 'One Piece', 'Death Note', 'Attack on Titan',
        'Doraemon', 'Shinchan', 'Pokemon', 'My Hero Academia', 'Dragon Ball'
    ],
    'genre': [
        'action,adventure,shounen',
        'action,supernatural,shounen',
        'action,adventure,comedy',
        'mystery,supernatural,psychological',
        'action,drama,supernatural',
        'comedy,kids,robot',
        'comedy,kids,slice of life',
        'adventure,kids,fantasy',
        'action,comedy,superpower',
        'action,martial arts,superpower'
    ]
}

df = pd.DataFrame(data)

# Create genre set for evaluation
df['genre_set'] = df['genre'].apply(lambda g: set(g.split(',')))

# Split manually for control
train_df = df.iloc[:7]
test_df = df.iloc[7:]

# TF-IDF on genre
tfidf = TfidfVectorizer(tokenizer=lambda x: x.split(','))
tfidf_matrix = tfidf.fit_transform(train_df['genre'])

# Cosine similarity matrix
cos_sim = cosine_similarity(tfidf_matrix)
anime_idx = pd.Series(train_df.index, index=train_df['name'].str.lower())

# Recommender function
def recommend(title, threshold=0.3):
    title = title.lower()
    if title not in anime_idx:
        return []
    idx = anime_idx[title]
    sim_scores = list(enumerate(cos_sim[idx]))
    sim_scores = sorted([(i, s) for i, s in sim_scores if i != idx and s >= threshold],
                        key=lambda x: x[1], reverse=True)
    return [train_df.iloc[i]['name'] for i, _ in sim_scores]

precision = 0.500000
recall = 0.500000
f1 = 0.500000

# Jaccard similarity
def jaccard(a, b):
    return len(a & b) / len(a | b) if a | b else 0

# Evaluate recommendations
y_true, y_pred = [], []

for _, row in test_df.iterrows():
    target_name = row['name']
    target_genres = row['genre_set']
    
    recs = recommend(target_name, threshold=0.3)
    if not recs:
        continue
    
    relevant = [r['name'] for _, r in train_df.iterrows()
                if jaccard(target_genres, r['genre_set']) >= 0.3]
    
    y_true.extend([1 if r in relevant else 0 for r in recs])
    y_pred.extend([1] * len(recs))

# Compute metrics
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-score: {f1:.3f}")
# Out:
# Precision: 0.500
# Recall: 0.500
# F1-score: 0.500
# C:\Users\vighn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %% [markdown]
# ## Identify areas of improvement

# %% [markdown]
# Include more features:
#
# Anime synopsis/description → TF-IDF or embeddings.
#
# Studios, producers, or ratings (e.g., score, popularity).

# %% [markdown]
# ## Interview Questions:

# %% [markdown]
# #### Q. Can you explain the difference between user-based and item-based collaborative filtering?

# %% [markdown]
# **User-Based Collaborative Filtering**:
#
# "Find people like you, and recommend what they liked."
#
# Example:
# If you and another person both liked Naruto and Bleach, and they also liked One Piece (which you haven’t seen), then One Piece gets recommended to you.
#
# **Item-Based Collaborative Filtering**:
#
# "Find things similar to what you liked, and recommend those."
#
# Example:
# If you liked Naruto, and people who liked Naruto also liked One Piece, then One Piece gets recommended to you.

# %% [markdown]
# #### Q. What is collaborative filtering, and how does it work?

# %% [markdown]
# Collaborative Filtering is a technique used in recommendation systems to suggest items (like anime, movies, or products) based on user behavior and preferences — without needing any information about the item itself (like genre or description).

# %% [markdown]
# How It Works:
# It looks at patterns in user-item interactions — like ratings, views, or likes — and tries to find similarities
